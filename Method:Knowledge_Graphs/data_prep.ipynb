# %% [markdown]
# ## Prepare Data for Knowledge Graph Creation

# %%
import pandas as pd
import json
import re
import os
import Levenshtein

# %%
# Load data
#filepath = '../scraping/articles/filtered_articles.json'
filepath = '../scraping/articles/all_articles.json'
with open(filepath, 'r') as file:
    articles = pd.read_json(filepath)

# %%
# Names used for replacement
name_dict = {
    'ARC': ['ARC'],
    'Babcock and Wilcox': ['Babcock'],
    'Berkeley': ['Berkeley'],
    'BWX': ['BWX'],
    'Elysium': ['Elysium'],
    'Flibe': ['Flibe'],
    'Framatome': ['Framatome'],
    'GE Hitachi': ['Hitachi', 'GEH'],
    'General Atomics': ['General Atomics'],
    'HolosGen': ['HolosGen', 'Holos'],
    'Holtec International': ['Holtec'],
    'Hyperion Power': ['Hyperion'],
    'Kairos Power': ['Kairos'],
    'Moltex Energy': ['Moltex'],
    'NANO Nuclear': ['NANO', 'NNE'],
    'NuScale': ['NuScale'],
    'Oak Ridge National Laboratory': ['Oak Ridge National Laboratory', 'ORNL'],
    'Oklo': ['Oklo'],
    'StarCore Nuclear': ['StarCore'],
    'TerraPower': ['TerraPower'],
    'Terrestial': ['Terrestial'],
    'ThorCon': ['ThorCon'],
    'Ultra Safe Nuclear Corporation': ['Ultra Safe Nuclear Corporation', 'USNC'],
    'Westinghouse': ['Westinghouse', 'WEC'],
    'X-Energy': ['X-energy']
}

# %% [markdown]
# ### Get frequency of names in articles (Optional)

# %%
# Get frequency of each start up name in each article
articles_with_frequency = []

for i in range(len(articles)):
    article = articles.iloc[i]
    url = article['url']
    title = article['title']
    sents = article['text']
    text = ' '.join(sents)

    new_article = {
        'url': url,
        'title': title,
        'text': sents,
    }

    for key, names in name_dict.items():
        frequency = 0
        
        for name in names:
            if name.isupper():
                pattern = rf'\b{re.escape(name)}\b|\({re.escape(name)}\)|\b{re.escape(name)}[-\w]*\b'
                frequency += len(re.findall(pattern, text))
            else:
                # Case-insensitive match for non-acronyms
                pattern = rf'\b{re.escape(name.lower())}\b|\({re.escape(name.lower())}\)|\b{re.escape(name.lower())}[-\w]*\b'
                frequency += len(re.findall(pattern, text.lower()))
        
        new_article[key] = frequency
    
    articles_with_frequency.append(new_article)

filepath = f'data/articles_with_frequency.json'
os.makedirs(os.path.dirname(filepath), exist_ok=True)
with open(filepath, 'w') as file:
    json.dump(articles_with_frequency, file, indent=4, ensure_ascii=False)

# %% [markdown]
# ### Choose base directory

# %%
#base_directory = 'data/triplets_with_frequency'
#base_directory = 'data/triplets_no_cutoff'
base_directory = 'data/triplets_all_time'

# Also: you'll need this later
with open('stopwords/countries.txt', 'r') as file:
    countries = [line.strip() for line in file]

with open('stopwords/cities.txt', 'r') as file:
    capitals = [line.strip() for line in file]

with open('stopwords/startups.txt', 'r') as file:
    startups = [line.strip() for line in file]

with open('stopwords/states.txt', 'r') as file:
    states = [line.strip() for line in file]

stopwords = countries + capitals + startups + states

# %% [markdown]
# ### Filter articles (optional)

# %%
SPLIT_FACTOR = 10 # Determines cutoff: 1 -> top 100%; 2 -> top 50%; 10 -> top 10%
base_directory = 'data/triplets_with_frequency'

#SPLIT_FACTOR = 1
#base_directory = 'data/triplets_no_cutoff' # for SP

with open('data/enriched_triplets.json', 'r') as file:
    all_triplets = json.load(file)

for name, name_list in name_dict.items():
    
    filepath = f"{base_directory}/{name.lower().replace(' ','_')}/{name.lower().replace(' ','_')}.json"
    with open(filepath, 'r') as file:
        articles = pd.read_json(filepath)
    
    if not articles.empty:

        # Sort by frequency, get first decile
        articles = articles.sort_values(by=['frequency'], ascending=False)
        cutoff = len(articles) // SPLIT_FACTOR
        articles = articles.iloc[:cutoff+1]

        # Next, get the triplets
        triplets = []
        length = len(articles)
        for i in range(length):
            article = articles.iloc[i]
            target_url = article['url']
            freq = int(article['frequency'])

            for instance in all_triplets:
                url = instance['url']
                if url == target_url:
                    triplets.append({
                        'url': url,
                        'triplets': instance['enriched_triplets'],
                        'target': name,
                        'frequency': freq,
                    })
    
        triplets_length = len(triplets)
        percent = triplets_length/length*100 if length > 0 else 0

        print(f'{name}: Triplets retrieved from {triplets_length} articles')

        filepath = f"{base_directory}/{name.lower().replace(' ','_')}/{name.lower().replace(' ','_')}_triplets.json"
        os.makedirs(os.path.dirname(filepath), exist_ok=True)

        with open(filepath, 'w') as file:
            json.dump(triplets, file, indent=4, ensure_ascii=False)
# Out:
# ARC: Triplets retrieved from 4 articles
# Babcock and Wilcox: Triplets retrieved from 2 articles
# Berkeley: Triplets retrieved from 3 articles
# BWX: Triplets retrieved from 6 articles
# Elysium: Triplets retrieved from 1 articles
# Flibe: Triplets retrieved from 2 articles
# Framatome: Triplets retrieved from 17 articles
# GE Hitachi: Triplets retrieved from 21 articles
# General Atomics: Triplets retrieved from 3 articles
# HolosGen: Triplets retrieved from 1 articles
# Holtec International: Triplets retrieved from 12 articles
# Kairos Power: Triplets retrieved from 2 articles
# Moltex Energy: Triplets retrieved from 4 articles
# NANO Nuclear: Triplets retrieved from 1 articles
# NuScale: Triplets retrieved from 19 articles
# Oak Ridge National Laboratory: Triplets retrieved from 7 articles
# Oklo: Triplets retrieved from 3 articles
# TerraPower: Triplets retrieved from 9 articles
# ThorCon: Triplets retrieved from 1 articles
# Ultra Safe Nuclear Corporation: Triplets retrieved from 5 articles
# Westinghouse: Triplets retrieved from 43 articles
# X-Energy: Triplets retrieved from 9 articles

# %%
# Preprocess enriched triplets (for case of no filtering) to make next step possible
if base_directory == 'data/triplets_all_time':
    with open('data/enriched_triplets.json', 'r') as file:
        all_triplets = json.load(file)

    triplets = []
    for instance in all_triplets:
        triplets.extend(instance['enriched_triplets'])

    filepath = f"{base_directory}/all_triplets.json"
    with open(filepath, 'w') as file:
        json.dump(triplets, file, indent=4, ensure_ascii=False)

# %% [markdown]
# ### Script for Preprocessing Triplets

# %%
exact_replacements = {
    # Demonyms
    'Russian': 'Russia', 'Chinese': 'Chinese', 
    'American': 'United States', 'British': 'United Kingdom', 'Polish': 'Poland',
    'Swedish': 'Sweden', 'French': 'France', 'South Korean': 'South Korea', 
    'Dutch': 'Netherlands', 'Ukranian': 'Ukraine',

    # Countries etc.
    'UK': 'United Kingdom', 'US': 'United States', 'UAE': 'United Arab Emirates',
    'Russian Federation': 'Russia', 'Czech': 'Czech Republic', 'Netherlands': 'Netherlands',
    'Korea': 'South Korea',
    'EU': 'European Union', 'UN': 'United Nations', 

    # Abbreviations
    'WEC': 'Westinghouse', 'USNC': 'Ultra Safe Nuclear Corporation', 'GEH': 'GE Hitachi', 'GA': 'General Atomics',
    'GFP': 'Global First Power', 'ORNL': 'Oak Ridge National Laboratory',
    'IAEA': 'International Atomic Energy Agency'
}

org_replacements = { # Replace if entity type == ORG (substring match)
    'ARC': 'ARC',
    'Babcock': 'Babcock and Wilcox',
    'BWX': 'BWX',
    'Elysium': 'Elysium',
    'Flibe': 'Flibe',
    'Framatome': 'Framatome',
    'Hitachi': 'GE Hitachi',
    'General Atomics': 'General Atomics',
    'Holos': 'HolosGen',
    'Holtec': 'Holtec International',
    'Hyperion': 'Hyperion Power',
    'Kairos': 'Kairos Power',
    'Moltex': 'Moltex Energy',
    'NANO': 'NANO Nuclear',
    'NuScale': 'NuScale',
    'Oak Ridge': 'Oak Ridge National Laboratory',
    'Oklo': 'Oklo',
    'StarCore': 'StarCore Nuclear',
    'TerraPower': 'TerraPower',
    'Terrestial': 'Terrestial',
    'ThorCon': 'ThorCon',
    'Ultra Safe Nuclear': 'Ultra Safe Nuclear Corporation',
    'Berkeley': 'Berkeley',
    'Westinghouse': 'Westinghouse',
    'X-Energy': 'X-Energy',

    'Point Lepreau': 'Point Lepreau NPP',
    'China General Nuclear ': 'China General Nuclear Power Corporation',
    'Clinch River': 'Clinch River Site',
    'East Tennessee Technology': 'East Tennessee Technology Park',
    'Fukushima': 'Fukushima',
    'Jacobs UK': 'Jacobs',
    'Korea Electric Power': 'Korea Electric Power Company',
    'Magnox': 'Magnox',
    'ORLEN Synthos': 'ORLEN Synthos Green Energy',
    'Rolls Royce': 'Rolls-Royce',
    'Sizewell': 'Sizewell C',
    'WEC': 'WEC Group',
    'Temelin': 'Temelin NPP',
    'TransAlta': 'TransAlta  Corporation'
}

per_replacements = { # Replace if entity type == PER (substring match)
    'Grossi': 'Rafael Grossi'
}

loc_replacements = {
    'Point Lepreau': 'Point Lepreau NPP'
}

letter_replacements = {
    'à': 'a', 'À': 'A',
    'á': 'a', 'Á': 'A',
    'ä': 'a', 'Ä': 'A',
    'ã': 'a', 'Ã': 'A',
    'å': 'a', 'Å': 'A',
    'ą': 'a', 'Ą': 'A',
    'ç': 'c', 'Ç': 'C',
    'č': 'c', 'Č': 'C',
    'ď': 'd', 'Ď': 'D',
    'é': 'e', 'É': 'E',
    'è': 'e', 'È': 'E',
    'ě': 'e', 'Ě': 'E',
    'ğ': 'g', 'Ğ': 'G',
    'í': 'i', 'Í': 'I',
    'ï': 'i', 'Ï': 'I',
    'ı': 'i', 'İ': 'I',
    'ł': 'l', 'Ł': 'L',
    'ł': 'l', 'Ł': 'L',
    'ñ': 'n', 'Ñ': 'N',
    'ň': 'n', 'Ň': 'N',
    'ń': 'n', 'Ń': 'N',
    'ó': 'o', 'Ó': 'O',
    'ö': 'o', 'Ö': 'O',
    'ô': 'o', 'Ô': 'O',
    'õ': 'o', 'Õ': 'O',
    'ø': 'o', 'Ø': 'O',
    'ř': 'r', 'Ř': 'R',
    'š': 's', 'Š': 'S',
    'ť': 't', 'Ť': 'T',
    'ú': 'u', 'Ú': 'U',
    'ü': 'u', 'Ü': 'U',
    'û': 'u', 'Û': 'U',
    'ù': 'u', 'Ù': 'U',
    'ý': 'y', 'Ý': 'Y',
    'ž': 'z', 'Ž': 'Z',
    '.': ' ', ' “': '',
    '&': 'and',
}

def custom_replacement(word, entity=None):
    new = None
    
    for letter, replacement in letter_replacements.items():
        word = word.replace(letter, replacement)
    
    lower_word = word.strip().lower()

    for key, replacement in exact_replacements.items():
        if lower_word == key.lower():
            new = replacement
    
    if entity == 'ORG':
        for org_key, replacement in org_replacements.items():
            if org_key.lower() in lower_word:
                new = replacement
    elif entity == 'PER':
        for per_key, replacement in per_replacements.items():
            if per_key.lower() in lower_word:
                new = replacement
    elif entity == 'LOC':
        for loc_key, replacement in loc_replacements.items():
            if loc_key.lower() in lower_word:
                new = replacement
    
    #if not new:
        #print(word, entity)
    #if new and new != word:
        #print(f"Before: {word}")
        #print(f"After: {new}")
    if not new:
        new = word
    return new

# %%
# Make into Excel for data prep
if base_directory == 'data/triplets_all_time':
    filepath = base_directory + '/all_triplets' # use the unfiltered data

    with open(filepath + '.json', 'r') as file:
        triplets = json.load(file)

    only_triplets = []
    for triplet in triplets:

        head = triplet['head']['word']
        h_ent = triplet['head']['entity']
        tail = triplet['tail']['word']
        t_ent = triplet['tail']['entity']

        # Drop triplets DistilBERT was not able to identify
        if h_ent == 'Unknown' or t_ent == 'Unknown':
            continue

        head = custom_replacement(head, h_ent)
        tail = custom_replacement(tail, t_ent)

        only_triplets.append({
            'head': head,
            'h_ent': h_ent,
            'relation': triplet['relation'],
            'tail': tail,
            't_ent': t_ent
        })

    df = pd.json_normalize(only_triplets)
    df = df.drop_duplicates()
    df.to_excel(filepath + '_no_dupes.xlsx', index=False)
    
else:
    for name in name_dict:
    
        filepath = f"{base_directory}/{name.lower().replace(' ', '_')}/{name.lower().replace(' ','_')}_triplets"

        try:
            with open(filepath + '.json', 'r') as file:
                data = json.load(file)
        except FileNotFoundError:
            continue

        only_triplets = []
        for instance in data:
            for triplet in instance['triplets']:

                head = triplet['head']['word']
                h_ent = triplet['head']['entity']
                tail = triplet['tail']['word']
                t_ent = triplet['tail']['entity']

                # Drop triplets DistilBERT was not able to identify
                if h_ent == 'Unknown' or t_ent == 'Unknown':
                    continue

                head = custom_replacement(head, h_ent)
                tail = custom_replacement(tail, t_ent)

                # Drop circular relations
                if head == tail and h_ent == t_ent:
                    continue

                only_triplets.append({
                    'head': head,
                    'h_ent': h_ent,
                    'relation': triplet['relation'],
                    'tail': tail,
                    't_ent': t_ent
                })

        df = pd.json_normalize(only_triplets)
        df = df.drop_duplicates()

        print(f"{name}: {len(df)} triplets")
        df.to_excel(filepath + '_no_dupes.xlsx', index=False)

# %% [markdown]
# ### Propagation Algoritm

# %%
# Get connected triplets
def propagate(entity_name, graph, triplets, visited, threshold=0.9):
    if entity_name in visited:
        return graph
    
    visited.add(entity_name)

    for triplet in triplets:
        head = triplet[0]
        tail = triplet[3]
        
        tail_sim = Levenshtein.ratio(tail.lower(), entity_name.lower())
        head_sim = Levenshtein.ratio(head.lower(), entity_name.lower())

        triplet_tuple = (head, triplet[1], tail, triplet[4], triplet[2])

        # Propagate inward: tail->head
        if tail_sim > threshold and triplet_tuple not in graph:
            graph.add(triplet_tuple)
            if head not in stopwords:
                print(f'Propagating inward from {entity_name} to {head} through {tail} (similarity: {tail_sim:.2f})')
                propagate(head, graph, triplets, visited, threshold)

        # Propagate outward: head->tail
        if head_sim > threshold and triplet_tuple not in graph:
            graph.add(triplet_tuple)
            if tail not in stopwords:
                print(f'Propagating outward from {entity_name} to {tail} through {head} (similarity: {head_sim:.2f})')
                propagate(tail, graph, triplets, visited, threshold)
    
    return graph

# %%
df = pd.read_excel('data/final_triplets.xlsx')
triplets = set(df.itertuples(index=False, name=None))
triplets = list(triplets)

results = {}
for name in name_dict:
    print(f"Now propagating for {name}...")
    graph = propagate(name, set(), triplets, set(), threshold=0.95)
    results[name] = list(graph)

filepath = f'{base_directory}/graphs.json'
print(f'Saving results to {filepath}...')
with open(filepath, 'w') as file:
    json.dump(results, file, indent=4, ensure_ascii=False)
# Out:
# Now propagating for ARC...
# Propagating inward from ARC to Charlotte through ARC (similarity: 1.00)
# Propagating outward from Charlotte to Belews Creek through Charlotte (similarity: 1.00)
# Propagating inward from Belews Creek to Roxboro through Belews Creek (similarity: 1.00)
# Propagating inward from ARC to Roman Estrada through ARC (similarity: 1.00)
# Propagating outward from Roman Estrada to NPPD through Roman Estrada (similarity: 1.00)
# Propagating inward from ARC to Andrey Baklitsky through ARC (similarity: 1.00)
# Propagating inward from ARC to Cleveland through ARC (similarity: 1.00)
# Propagating outward from Cleveland to Glenn Research Centre through Cleveland (similarity: 1.00)
# Propagating inward from ARC to Bogdan Neculaes through ARC (similarity: 1.00)
# Propagating inward from ARC to Craig Stover through ARC (similarity: 1.00)
# Propagating inward from ARC to Lukasz Gadowski through ARC (similarity: 1.00)
# Propagating inward from ARC to Petten through ARC (similarity: 1.00)
# Propagating outward from Petten to High Flux Reactor through Petten (similarity: 1.00)
# Propagating outward from Petten to Curium through Petten (similarity: 1.00)
# Propagating inward from Curium to Ciril Faia through Curium (similarity: 1.00)
# Propagating outward from Curium to Curiumn through Curium (similarity: 1.00)
# Propagating outward from Petten to Energy and Health Campus through Petten (similarity: 1.00)
# Propagating outward from Petten to Thorizon through Petten (similarity: 1.00)
# Propagating outward from Thorizon to EDF through Thorizon (similarity: 1.00)
# Propagating outward from Pietro Barabaschi to ITER through Pietro Barabaschi (similarity: 1.00)
# Propagating inward from ITER to Pietro Baraba through ITER (similarity: 1.00)
# Propagating inward from ITER to Loarte through ITER (similarity: 1.00)
# Propagating inward from ITER to MHI through ITER (similarity: 1.00)
# Propagating outward from MHI to JAEA through MHI (similarity: 1.00)
# Propagating inward from JAEA to Monju through JAEA (similarity: 1.00)
# Propagating inward from Monju to Joyo through Monju (similarity: 1.00)
# Propagating inward from Joyo to Tokai through Joyo (similarity: 1.00)
# Propagating inward from Tokai to Mitsubishi Materials Corporation through Tokai (similarity: 1.00)
# Propagating inward from JAEA to Masanori Koguchi through JAEA (similarity: 1.00)
# Propagating outward from Masanori Koguchi to Cavendish Nuclear through Masanori Koguchi (similarity: 1.00)
# Propagating inward from Cavendish Nuclear to Hartlepool through Cavendish Nuclear (similarity: 1.00)
# Propagating outward from Hartlepool to Teesside University through Hartlepool (similarity: 1.00)
# Propagating inward from Teesside University to Matthew Cotton through Teesside University (similarity: 1.00)
# Propagating inward from Hartlepool to Tees Valley through Hartlepool (similarity: 1.00)
# Propagating outward from Tees Valley to Darlington through Tees Valley (similarity: 1.00)
# Propagating inward from Darlington to OPG through Darlington (similarity: 1.00)
# Propagating outward from OPG to SaskPower through OPG (similarity: 1.00)
# Propagating inward from SaskPower to Jay Wileman through SaskPower (similarity: 1.00)
# Propagating outward from Jay Wileman to Fermi Energia through Jay Wileman (similarity: 1.00)
# Propagating inward from Fermi Energia to Marti Jeltsov through Fermi Energia (similarity: 1.00)
# Propagating inward from Fermi Energia to Kalev Kallemets through Fermi Energia (similarity: 1.00)
# Propagating outward from Kalev Kallemets to Fermi Energia through Kalev Kallemet (similarity: 0.97)
# Propagating inward from Fermi Energia to Henri Ormus through Fermi Energia (similarity: 1.00)
# Propagating inward from SaskPower to Estevan through SaskPower (similarity: 1.00)
# Propagating outward from Estevan to Grant Devine Lake through Estevan (similarity: 1.00)
# Propagating inward from Estevan to Roy Ludwig through Estevan (similarity: 1.00)
# Propagating inward from Estevan to Regina through Estevan (similarity: 1.00)
# Propagating inward from SaskPower to Rupen Pandya through SaskPower (similarity: 1.00)
# Propagating outward from Rupen Pandya to SaskPower through Rupen Pandy (similarity: 0.96)
# Propagating inward from SaskPower to Don Morgan through SaskPower (similarity: 1.00)
# Propagating inward from OPG to Bruce County through OPG (similarity: 1.00)
# Propagating outward from Bruce County to Pickering through Bruce County (similarity: 1.00)
# Propagating outward from Pickering to Douglas Point through Pickering (similarity: 1.00)
# Propagating outward from Pickering to OPG through Pickering (similarity: 1.00)
# Propagating outward from OPG to CanAtom through OPG (similarity: 1.00)
# Propagating inward from OPG to Darlington through OPG (similarity: 1.00)
# Propagating inward from OPG to Subo Sinnathamby through OPG (similarity: 1.00)
# Propagating inward from OPG to Ken Hartwick through OPG (similarity: 1.00)
# Propagating outward from Ken Hartwick to Ontario Power Generation through Ken Hartwick (similarity: 1.00)
# Propagating outward from Ontario Power Generation to Darlington through Ontario Power Generation (similarity: 1.00)
# Propagating inward from Ontario Power Generation to Todd Smith through Ontario Power Generation (similarity: 1.00)
# Propagating outward from Todd Smith to Bruce Power through Todd Smith (similarity: 1.00)
# Propagating outward from Bruce Power to Asset Management through Bruce Power (similarity: 1.00)
# Propagating inward from Asset Management to Bruce Power through Asset Management (similarity: 1.00)
# Propagating inward from Bruce Power to James Scongack through Bruce Power (similarity: 1.00)
# Propagating inward from Bruce Power to Richard Horro through Bruce Power (similarity: 1.00)
# Propagating inward from Bruce Power to Mike Renche through Bruce Power (similarity: 1.00)
# Propagating outward from Mike Renche to Bruce Power through Mike Renche (similarity: 1.00)
# Propagating inward from Bruce Power to David Furr through Bruce Power (similarity: 1.00)
# Propagating inward from Bruce Power to Mike Rencheck through Bruce Power (similarity: 1.00)
# Propagating inward from Bruce Power to Bruce through Bruce Power (similarity: 1.00)
# Propagating outward from Bruce to Bruce A through Bruce (similarity: 1.00)
# Propagating inward from Bruce to Huron through Bruce (similarity: 1.00)
# Propagating inward from Bruce to Bruce through Bruce (similarity: 1.00)
# Propagating inward from Bruce Power to Darlington through Bruce Power (similarity: 1.00)
# Propagating inward from Ontario Power Generation to Kim Laurits through Ontario Power Generation (similarity: 1.00)
# Propagating outward from OPG to Tennessee Valley Authority through OPG (similarity: 1.00)
# Propagating inward from Tennessee Valley Authority to Jeff Lyash through Tennessee Valley Authority (similarity: 1.00)
# Propagating outward from Jeff Lyash to TVA through Jeff Lyash (similarity: 1.00)
# Propagating inward from TVA to Scott Hunnewell through TVA (similarity: 1.00)
# Propagating inward from TVA to Tennessee Valley through TVA (similarity: 1.00)
# Propagating inward from TVA to Clinch River through TVA (similarity: 1.00)
# Propagating outward from Clinch River to Fiedler through Clinch River (similarity: 1.00)
# Propagating inward from Tennessee Valley Authority to Hermes through Tennessee Valley Authority (similarity: 1.00)
# Propagating outward from Hermes to TRISO Development Lab through Hermes (similarity: 1.00)
# Propagating outward from TRISO Development Lab to Hermes through TRISO Development Lab (similarity: 1.00)
# Propagating inward from Hermes to Oak Ridge through Hermes (similarity: 1.00)
# Propagating outward from Oak Ridge to East Tennessee Technology Park through Oak Ridge (similarity: 1.00)
# Propagating inward from East Tennessee Technology Park to Oak Ridge through East Tennessee Technology Park (similarity: 1.00)
# Propagating outward from Oak Ridge to Clinch River Site through Oak Ridge (similarity: 1.00)
# Propagating outward from Oak Ridge to Savannah River through Oak Ridge (similarity: 1.00)
# Propagating outward from Oak Ridge to Horizon Center Industrial Park through Oak Ridge (similarity: 1.00)
# Propagating outward from Oak Ridge to US Nuclear Regulatory Commission through Oak Ridge (similarity: 1.00)
# Propagating inward from US Nuclear Regulatory Commission to Monticello through US Nuclear Regulatory Commission (similarity: 1.00)
# Propagating inward from Monticello to Minneapolis through Monticello (similarity: 1.00)
# Propagating inward from Minneapolis to Xcel Energy through Minneapolis (similarity: 1.00)
# Propagating outward from Xcel Energy to Monticello through Xcel Energy (similarity: 1.00)
# Propagating inward from Jacobs to Bruce Chalmers through Jacobs (similarity: 1.00)
# Propagating inward from Jacobs to Naarea through Jacobs (similarity: 1.00)
# Propagating inward from Naarea to Jean Luc Alexandre through NAAREA (similarity: 1.00)
# Propagating inward from Naarea to James through Naarea (similarity: 1.00)
# Propagating inward from Naarea to newcleo through Naarea (similarity: 1.00)
# Propagating inward from newcleo to Ludovic Vandendriesche through newcleo (similarity: 1.00)
# Propagating outward from Ludovic Vandendriesche to newcleo SA through Ludovic Vandendriesche (similarity: 1.00)
# Propagating outward from newcleo to Stefano Buono through Newcleo (similarity: 1.00)
# Propagating outward from Stefano Buono to Fincantieri through Stefano Buono (similarity: 1.00)
# Propagating inward from Fincantieri to Pierroberto Folgiero through Fincantieri (similarity: 1.00)
# Propagating outward from Stefano Buono to newcleo through Stefano Buono (similarity: 1.00)
# Propagating outward from Stefano Buono to Newcleo through Stefano Buono (similarity: 1.00)
# Propagating outward from Newcleo to Orano through Newcleo (similarity: 1.00)
# Propagating outward from Newcleo to LSE through newcleo (similarity: 1.00)
# Propagating inward from LSE to Susana Mourato through LSE (similarity: 1.00)
# Propagating inward from LSE to Eric Neumayer through LSE (similarity: 1.00)
# Propagating outward from Newcleo to Rutschi Group through newcleo (similarity: 1.00)
# Propagating outward from Newcleo to Tosto Group through Newcleo (similarity: 1.00)
# Propagating inward from Tosto Group to Luca Tosto through Tosto Group (similarity: 1.00)
# Propagating inward from Tosto Group to Newcleo through Tosto Group (similarity: 1.00)
# Propagating outward from Newcleo to National Nuclear Laboratory through newcleo (similarity: 1.00)
# Propagating inward from National Nuclear Laboratory to Leicester through National Nuclear Laboratory (similarity: 1.00)
# Propagating inward from National Nuclear Laboratory to Cheshire through National Nuclear Laboratory (similarity: 1.00)
# Propagating outward from Cheshire to Warrington through Cheshire (similarity: 1.00)
# Propagating outward from Warrington to National Nuclear Laboratory through Warrington (similarity: 1.00)
# Propagating inward from Warrington to Moltex Energy through Warrington (similarity: 1.00)
# Propagating inward from National Nuclear Laboratory to Urenco through National Nuclear Laboratory (similarity: 1.00)
# Propagating inward from Urenco to Almelo through Urenco (similarity: 1.00)
# Propagating inward from Almelo to Urenco through Almelo (similarity: 1.00)
# Propagating inward from Almelo to Urenco through Almelo (similarity: 1.00)
# Propagating inward from Urenco to Boris Schu through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Chris Pye through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Ad Louter through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Chris Chater through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Nic Brunetti through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Boris Schucht through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Emilie Isaacs through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Laurent Odeh through Urenco (similarity: 1.00)
# Propagating inward from Urenco to David Fletcher through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Sexton through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Seaborg through Urenco (similarity: 1.00)
# Propagating inward from Seaborg to Power Barges through Seaborg (similarity: 1.00)
# Propagating inward from Power Barges to Seaborg through Power Barge (similarity: 0.96)
# Propagating outward from Seaborg to Compact Molten Salt Reactor through Seaborg (similarity: 1.00)
# Propagating inward from Seaborg to Navid Samandari through Seaborg (similarity: 1.00)
# Propagating outward from Navid Samandari to Seaborg Technologies through Navid Samandari (similarity: 1.00)
# Propagating inward from Seaborg Technologies to Klaus Nyengaard through Seaborg Technologies (similarity: 1.00)
# Propagating outward from Seaborg to Norsk Kjernekraft through Seaborg (similarity: 1.00)
# Propagating inward from Norsk Kjernekraft to Jonny Hesthammer through Norsk Kjernekraft (similarity: 1.00)
# Propagating inward from Norsk Kjernekraft to Oygarden through Norsk Kjernekraft (similarity: 1.00)
# Propagating outward from Oygarden to Kollsnes through Oygarden (similarity: 1.00)
# Propagating inward from Oygarden to Bergen through Oygarden (similarity: 1.00)
# Propagating inward from Oygarden to Vestland County through Oygarden (similarity: 1.00)
# Propagating inward from Norsk Kjernekraft to Halden through Norsk Kjernekraft (similarity: 1.00)
# Propagating outward from Halden to Halden Kjernekraft through Halden (similarity: 1.00)
# Propagating outward from Halden to Kjeller through Halden (similarity: 1.00)
# Propagating inward from Kjeller to Holand through Kjeller (similarity: 1.00)
# Propagating outward from Holand to Aurskog through Holand (similarity: 1.00)
# Propagating inward from Halden to Ostfold through Halden (similarity: 1.00)
# Propagating outward from Seaborg to CMSR through Seaborg (similarity: 1.00)
# Propagating outward from Seaborg to Samandari through Seaborg (similarity: 1.00)
# Propagating inward from Seaborg to South Korea through Seaborg (similarity: 1.00)
# Propagating inward from Urenco to Pye through Urenco (similarity: 1.00)
# Propagating outward from Urenco to South Korea through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Forman through Urenco (similarity: 1.00)
# Propagating outward from Forman to Hale through Forman (similarity: 1.00)
# Propagating outward from Forman to Urenco through Forman (similarity: 1.00)
# Propagating inward from Urenco to South Korea through Urenco (similarity: 1.00)
# Propagating inward from Urenco to NetZero through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Energoatom through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Orano through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Stephens through Urenco (similarity: 1.00)
# Propagating outward from Stephens to TMF through Stephens (similarity: 1.00)
# Propagating inward from TMF to Capenhurst through TMF (similarity: 1.00)
# Propagating outward from Capenhurst to Stephens through Capenhurst (similarity: 1.00)
# Propagating inward from Capenhurst to Urenco through Capenhurst (similarity: 1.00)
# Propagating inward from TMF to Richard Stephens through TMF (similarity: 1.00)
# Propagating inward from Urenco to Energoatom through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Bechtel through Urenco (similarity: 1.00)
# Propagating inward from Bechtel to Brian Hartman through Bechtel (similarity: 1.00)
# Propagating inward from Bechtel to Craig Albert through Bechtel (similarity: 1.00)
# Propagating inward from Bechtel to Ahmet Tokpinar through Bechtel (similarity: 1.00)
# Propagating inward from Bechtel to John Howanitz through Bechtel (similarity: 1.00)
# Propagating inward from Bechtel to Jared DeMeritt through Bechtel (similarity: 1.00)
# Propagating inward from Urenco to Hidde Baars through Urenco (similarity: 1.00)
# Propagating inward from Urenco to Dave Sexton through Urenco (similarity: 1.00)
# Propagating outward from Urenco to Springfields Fuels Ltd through Urenco (similarity: 1.00)
# Propagating inward from Springfields Fuels Ltd to Lancashire through Springfields Fuels Ltd (similarity: 1.00)
# Propagating outward from Lancashire to Bay Hydrogen Hub through Lancashire (similarity: 1.00)
# Propagating outward from Lancashire to Studsvik through Lancashire (similarity: 1.00)
# Propagating inward from Studsvik to VTT through Studsvik (similarity: 1.00)
# Propagating inward from VTT to Jussi Manninen through VTT (similarity: 1.00)
# Propagating inward from Studsvik to Dongguk through Studsvik (similarity: 1.00)
# Propagating inward from Studsvik to LeadCold through Studsvik (similarity: 1.00)
# Propagating outward from LeadCold to Blykalla through Leadcold (similarity: 1.00)
# Propagating inward from Blykalla to Nykoping through Blykalla (similarity: 1.00)
# Propagating outward from Nykoping to Studsvik through Nykoping (similarity: 1.00)
# Propagating inward from LeadCold to Jacob Stedman through Leadcold (similarity: 1.00)
# Propagating outward from Jacob Stedman to LeadCold through Jacob Stedman (similarity: 1.00)
# Propagating outward from Lancashire to Westinghouse Springfields through Lancashire (similarity: 1.00)
# Propagating outward from Lancashire to Preston through Lancashire (similarity: 1.00)
# Propagating outward from Preston to National Nuclear Laboratory through Preston (similarity: 1.00)
# Propagating inward from Preston to North West through Preston (similarity: 1.00)
# Propagating outward from Preston to Springfields Fuels through Preston (similarity: 1.00)
# Propagating inward from Springfields Fuels to Lancashire through Springfields Fuels (similarity: 1.00)
# Propagating outward from Lancashire to Morecambe through Lancashire (similarity: 1.00)
# Propagating outward from Lancashire to Heysham through Lancashire (similarity: 1.00)
# Propagating inward from Heysham to Liverpool through Heysham (similarity: 1.00)
# Propagating inward from Heysham to Torness through Heysham (similarity: 1.00)
# Propagating inward from Torness to Hartlepool through Torness (similarity: 1.00)
# Propagating inward from Torness to Hunterston through Torness (similarity: 1.00)
# Propagating inward from Hunterston to Sellafield through Hunterston (similarity: 1.00)
# Propagating outward from Sellafield to Onkalo through Sellafield (similarity: 1.00)
# Propagating inward from Onkalo to Olkiluoto through Onkalo (similarity: 1.00)
# Propagating inward from Olkiluoto to Teollisuuden Voima Oyj through Olkiluoto (similarity: 1.00)
# Propagating outward from Teollisuuden Voima Oyj to Olkiluoto through Teollisuuden Voima Oyj (similarity: 1.00)
# Propagating outward from Teollisuuden Voima Oyj to Olkiluoto 3 through Teollisuuden Voima Oyj (similarity: 1.00)
# Propagating inward from Teollisuuden Voima Oyj to Vakkilainen through Teollisuuden Voima Oyj (similarity: 1.00)
# Propagating outward from Teollisuuden Voima Oyj to Olkiluo through Teollisuuden Voima Oyj (similarity: 1.00)
# Propagating outward from Olkiluoto to Loviisa through Olkiluoto (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Roddy Miller through Sellafield Ltd (similarity: 1.00)
# Propagating outward from Roddy Miller to Sellafield through Roddy Miller (similarity: 1.00)
# Propagating outward from Sellafield Ltd to Cleator Moor through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Carl Carruthers through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Jenifer Carruthers through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Charlotte Brew through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to ONR through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to ONR through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Martin Chown through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Neil Rogerson through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Chris Hope through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to David Campbell through Sellafield Ltd (similarity: 1.00)
# Propagating inward from Sellafield Ltd to Cumbria through Sellafield Ltd (similarity: 1.00)
# Propagating outward from Cumbria to Whitehaven through Cumbria (similarity: 1.00)
# Propagating outward from Cumbria to Theddlethorpe through Cumbria (similarity: 1.00)
# Propagating inward from Theddlethorpe to South Copeland through Theddlethorpe (similarity: 1.00)
# Propagating inward from South Copeland to Cumbria through South Copeland (similarity: 1.00)
# Propagating inward from Theddlethorpe to Lincolnshire through Theddlethorpe (similarity: 1.00)
# Propagating outward from Cumbria to LLW through Cumbria (similarity: 1.00)
# Propagating outward from Cumbria to Drigg through Cumbria (similarity: 1.00)
# Propagating outward from Cumbria to Forth through Cumbria (similarity: 1.00)
# Propagating inward from Forth to Mark Telford through Forth (similarity: 1.00)
# Propagating outward from Cumbria to Copeland through Cumbria (similarity: 1.00)
# Propagating outward from Cumbria to Kirksanton through Cumbria (similarity: 1.00)
# Propagating outward from Cumbria to Moorside through Cumbria (similarity: 1.00)
# Propagating outward from Moorside to Wylfa through Moorside (similarity: 1.00)
# Propagating inward from Wylfa to Oldbury through Wylfa (similarity: 1.00)
# Propagating outward from Oldbury to Magnox through Oldbury (similarity: 1.00)
# Propagating inward from Magnox to Simon Bowen through Magnox (similarity: 1.00)
# Propagating outward from Simon Bowen to GBN through Simon Bowen (similarity: 1.00)
# Propagating outward from Simon Bowen to Johnson through Simon Bowen (similarity: 1.00)
# Propagating outward from Johnson to Sizewell C through Johnson (similarity: 1.00)
# Propagating outward from Sizewell C to Hinkley Point C through Sizewell C (similarity: 1.00)
# Propagating inward from Hinkley Point C to South West through Hinkley Point C (similarity: 1.00)
# Propagating inward from South West to James Barker through South West (similarity: 1.00)
# Propagating inward from Hinkley Point C to Somerset through Hinkley Point C (similarity: 1.00)
# Propagating outward from Somerset to Hinkley through Somerset (similarity: 1.00)
# Propagating inward from Hinkley to Sizewell through Hinkley (similarity: 1.00)
# Propagating outward from Oxford to Culham Campus through Oxford (similarity: 1.00)
# Propagating outward from Culham Campus to UKAEA through Culham Campus (similarity: 1.00)
# Propagating inward from Tractebel to Fabio Nouchy through Tractebel (similarity: 1.00)
# Propagating inward from Tractebel to Renaud Crassous through Tractebel (similarity: 1.00)
# Propagating outward from Renaud Crassous to Nuward through Renaud Crassous (similarity: 1.00)
# Propagating outward from Nuward to EDF Group through NUWARD (similarity: 1.00)
# Propagating inward from EDF Group to Bernard Salha through EDF Group (similarity: 1.00)
# Propagating inward from EDF Group to Xavier Ursat through EDF Group (similarity: 1.00)
# Propagating outward from Xavier Ursat to EDF through Xavier Ursat (similarity: 1.00)
# Propagating outward from Xavier Ursat to Gifen through Xavier Ursat (similarity: 1.00)
# Propagating inward from EDF Group to Luc Remont through EDF Group (similarity: 1.00)
# Propagating outward from Luc Remont to EDF through Luc Remont (similarity: 1.00)
# Propagating inward from Nuward to Renaud Crassous through NUWARD (similarity: 1.00)
# Propagating inward from Tractebel to Paulo Coelho through Tractebel (similarity: 1.00)
# Propagating inward from Tractebel to Vincent Schryvers through Tractebel (similarity: 1.00)
# Propagating outward from Tractebel to Gasthuisberg through Tractebel (similarity: 1.00)
# Propagating inward from Tractebel to Kiki Lauwers through Tractebel (similarity: 1.00)
# Propagating outward from Kiki Lauwers to Thorizon through Kiki Lauwers (similarity: 1.00)
# Propagating outward from Kiki Lauwers to Thorizon through Kiki Lauwer (similarity: 0.96)
# Propagating inward from Tractebel to Denis Dumont through Tractebel (similarity: 1.00)
# Propagating inward from Tractebel to Hinkley Point through Tractebel (similarity: 1.00)
# Propagating inward from Tractebel to Andrea Carletto through Tractebel (similarity: 1.00)
# Propagating outward from Tractebel to Engie through Tractebel (similarity: 1.00)
# Propagating inward from Engie to Catherine MacGregor through Engie (similarity: 1.00)
# Propagating inward from Tractebel to Altrad Endel through Tractebel (similarity: 1.00)
# Propagating inward from Altrad Endel to Madany Lias through Altrad Endel (similarity: 1.00)
# Propagating inward from Hinkley Point to Ricardo through Hinkley Point (similarity: 1.00)
# Propagating inward from Hinkley Point to Somerset through Hinkley Point (similarity: 1.00)
# Propagating inward from Hinkley Point to Stuart Crooks through Hinkley Point (similarity: 1.00)
# Propagating outward from Stuart Crooks to Hinkley Point C through Stuart Crooks (similarity: 1.00)
# Propagating inward from Sizewell to Magnox through Sizewell (similarity: 1.00)
# Propagating inward from Sizewell to EDF through Sizewell (similarity: 1.00)
# Propagating outward from Sizewell to Wylfa through Sizewell (similarity: 1.00)
# Propagating inward from Sizewell to Nigel Cann through Sizewell (similarity: 1.00)
# Propagating outward from Nigel Cann to Sizewell C through Nigel Cann (similarity: 1.00)
# Propagating outward from Nigel Cann to Hinkley Point C through Nigel Cann (similarity: 1.00)
# Propagating inward from Sizewell to Brown through Sizewell (similarity: 1.00)
# Propagating inward from Sizewell to Suffolk through Sizewell (similarity: 1.00)
# Propagating outward from Suffolk to Leiston through Suffolk (similarity: 1.00)
# Propagating outward from Suffolk to Norfolk through Suffolk (similarity: 1.00)
# Propagating inward from Suffolk to Jenny Kirtley through Suffolk (similarity: 1.00)
# Propagating outward from Jenny Kirtley to TASC through Jenny Kirtley (similarity: 1.00)
# Propagating inward from TASC to Suffolk through TASC (similarity: 1.00)
# Propagating inward from Suffolk to Boris Johnson through Suffolk (similarity: 1.00)
# Propagating outward from Boris Johnson to Jeremy Hunt through Boris Johnson (similarity: 1.00)
# Propagating outward from Jeremy Hunt to BBC through Jeremy Hunt (similarity: 1.00)
# Propagating outward from BBC to Wylfa through BBC (similarity: 1.00)
# Propagating inward from BBC to Great British Energy through BBC (similarity: 1.00)
# Propagating inward from BBC to John Curtice through BBC (similarity: 1.00)
# Propagating inward from Jeremy Hunt to Tony Blair through Jeremy Hunt (similarity: 1.00)
# Propagating outward from Suffolk to Hinkley through Suffolk (similarity: 1.00)
# Propagating outward from Suffolk to Sizewell C through Suffolk (similarity: 1.00)
# Propagating outward from Suffolk to Sizewell through Suffolk (similarity: 1.00)
# Propagating outward from Suffolk to Sizewell C through Suffolk (similarity: 1.00)
# Propagating outward from Sizewell to Wylfa through Sizewell (similarity: 1.00)
# Propagating inward from Sizewell to Julia Pyke through Sizewell (similarity: 1.00)
# Propagating outward from Julia Pyke to Sizewell C through Julia Pyke (similarity: 1.00)
# Propagating outward from Julia Pyke to EDF through Julia Pyke (similarity: 1.00)
# Propagating outward from Somerset to EDF Energy through Somerset (similarity: 1.00)
# Propagating outward from EDF Energy to Hartlepool through EDF Energy (similarity: 1.00)
# Propagating inward from EDF Energy to Hartlepool NPP through EDF Energy (similarity: 1.00)
# Propagating inward from EDF Energy to Simone Rossi through EDF Energy (similarity: 1.00)
# Propagating outward from Simone Rossi to EDF through Simone Rossi (similarity: 1.00)
# Propagating inward from EDF Energy to Mark Hartley through EDF Energy (similarity: 1.00)
# Propagating outward from Somerset to River Parrett through Somerset (similarity: 1.00)
# Propagating inward from Hinkley Point C to Britain through Hinkley Point C (similarity: 1.00)
# Propagating inward from Hinkley Point C to Twitter through Hinkley Point C (similarity: 1.00)
# Propagating inward from Hinkley Point C to Chris Fayers through Hinkley Point C (similarity: 1.00)
# Propagating inward from Hinkley Point C to Taishan through Hinkley Point C (similarity: 1.00)
# Propagating inward from Taishan to Guangdong through Taishan (similarity: 1.00)
# Propagating outward from Guangdong to Shenzhen through Guangdong (similarity: 1.00)
# Propagating outward from Guangdong to Lufeng through Guangdong (similarity: 1.00)
# Propagating inward from Lufeng to Sanmen through Lufeng (similarity: 1.00)
# Propagating outward from Sanmen to Haiyang through Sanmen (similarity: 1.00)
# Propagating inward from Haiyang to Jiaodong through Haiyang (similarity: 1.00)
# Propagating inward from Haiyang to Rushan through Haiyang (similarity: 1.00)
# Propagating inward from Haiyang to Shandong through Haiyang (similarity: 1.00)
# Propagating outward from Shandong to Shidaowan through Shandong (similarity: 1.00)
# Propagating inward from Shidaowan to Shandong Province through Shidaowan (similarity: 1.00)
# Propagating outward from Jongdoo Kim to Doosan through Jongdoo Kim (similarity: 1.00)
# Propagating outward from Jongdoo Kim to Doosan through Jongdoo Kim (similarity: 1.00)
# Propagating inward from Doosan to South Korea through Doosan (similarity: 1.00)
# Propagating inward from Doosan to South Korea through Doosan (similarity: 1.00)
# Propagating inward from Doosan to Clay Sell through Doosan (similarity: 1.00)
# Propagating outward from Clay Sell to Paragon through Clay Sell (similarity: 1.00)
# Propagating outward from Paragon to Martinez through Paragon (similarity: 1.00)
# Propagating inward from Paragon to Doug VanTassell through Paragon (similarity: 1.00)
# Propagating outward from Doug VanTassell to Paragon Energy Services through Doug VanTassell (similarity: 1.00)
# Propagating outward from Clay Sell to Dow through Clay Sell (similarity: 1.00)
# Propagating outward from Dow to Energy Northwest through Dow (similarity: 1.00)
# Propagating outward from Energy Northwest to Columbia Generating Station through Energy Northwest (similarity: 1.00)
# Propagating inward from Columbia Generating Station to Richland through Columbia Generating Station (similarity: 1.00)
# Propagating inward from Richland to Russ Watson through Richland (similarity: 1.00)
# Propagating outward from Richland to Fluid Controls and Components through Richland (similarity: 1.00)
# Propagating inward from Energy Northwest to Columbia through Energy Northwest (similarity: 1.00)
# Propagating outward from Energy Northwest to Curio through Energy Northwest (similarity: 1.00)
# Propagating outward from Curio to Ed McGinnis through Curio (similarity: 1.00)
# Propagating outward from Ed McGinnis to Curio through Ed McGinnis (similarity: 1.00)
# Propagating inward from Curio to Edward McGinnis through Curio (similarity: 1.00)
# Propagating inward from Edward McGinnis to Curio through Edward McGinnis (similarity: 1.00)
# Propagating inward from Energy Northwest to Bob Schuetz through Energy Northwest (similarity: 1.00)
# Propagating inward from Dow to Edward Stones through Dow (similarity: 1.00)
# Propagating outward from Dow to Seadrift through Dow (similarity: 1.00)
# Propagating outward from Dow to US Gulf Coast through Dow (similarity: 1.00)
# Propagating inward from Dow to Jim Fitterling through Dow (similarity: 1.00)
# Propagating outward from Jim Fitterling to Dow through Jim Fitterling (similarity: 1.00)
# Propagating inward from Doosan to South Korea through Doosan (similarity: 1.00)
# Propagating outward from South Korea to Okpo through South Korea (similarity: 1.00)
# Propagating inward from South Korea to Yoon Suk through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Hanaro through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Sawhney through South Korea (similarity: 1.00)
# Propagating inward from South Korea to SK Innovation through South Korea (similarity: 1.00)
# Propagating inward from SK Innovation to SK Group through SK Innovation (similarity: 1.00)
# Propagating outward from South Korea to Doosan Enerbility through South Korea (similarity: 1.00)
# Propagating outward from South Korea to KAERI through South Korea (similarity: 1.00)
# Propagating inward from South Korea to Lee Chang ya through South Korea (similarity: 1.00)
# Propagating outward from Lee Chang ya to South Korea through Lee Chang ya (similarity: 1.00)
# Propagating inward from South Korea to Samsung CandT Corporation through South Korea (similarity: 1.00)
# Propagating outward from South Korea to KAER through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Wolsong Nuclear Power Plant through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Shin Hanul NPP through South Korea (similarity: 1.00)
# Propagating inward from South Korea to Shin Wonsik through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Gunsan through South Korea (similarity: 1.00)
# Propagating inward from South Korea to Lee Chang Yang through South Korea (similarity: 1.00)
# Propagating inward from South Korea to Shin Hanul through South Korea (similarity: 1.00)
# Propagating inward from Shin Hanul to Ulchin County through Shin Hanul (similarity: 1.00)
# Propagating inward from Shin Hanul to South Korea through Shin Hanul (similarity: 1.00)
# Propagating inward from Shin Hanul to South Korea through Shin Hanul (similarity: 1.00)
# Propagating outward from South Korea to Gulf through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Busan through South Korea (similarity: 1.00)
# Propagating outward from Busan to Kori NPP through Busan (similarity: 1.00)
# Propagating outward from Busan to Pukyong National University through Busan (similarity: 1.00)
# Propagating outward from Busan to South Korea through Busan (similarity: 1.00)
# Propagating inward from Busan to South Korea through Busan (similarity: 1.00)
# Propagating inward from South Korea to Yoon Suk-ye through South Korea (similarity: 1.00)
# Propagating outward from Yoon Suk-ye to South Korea through Yoon Suk-ye (similarity: 1.00)
# Propagating inward from South Korea to South Korea through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Pacific Island through South Korea (similarity: 1.00)
# Propagating outward from South Korea to HD Hyundai through South Korea (similarity: 1.00)
# Propagating inward from HD Hyundai to HD Hyundai through HD Hyundai (similarity: 1.00)
# Propagating inward from HD Hyundai to Park Sang min through HD Hyundai (similarity: 1.00)
# Propagating inward from South Korea to Yoon Suk Yeol through South Korea (similarity: 1.00)
# Propagating inward from South Korea to South Korea through South Korea (similarity: 1.00)
# Propagating inward from South Korea to Chu Kwang through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Futami Plant through South Korea (similarity: 1.00)
# Propagating outward from South Korea to Changwon through South Korea (similarity: 1.00)
# Propagating inward from Changwon to South Gyeongsang Province through Changwon (similarity: 1.00)
# Propagating inward from Kexim to Hee-sung Yoon through Kexim (similarity: 1.00)
# Propagating outward from J  Clay Sell to X through J Clay Sell (similarity: 0.96)
# Propagating inward from X to Kam Ghaffarian through X (similarity: 1.00)
# Saving results to data/triplets_all_time/graphs.json...

# %%
# For UNFILTERED sub selection of articles
results = {}
for name in name_dict:

    #filepath = f"{base_directory}/{name.lower().replace(' ', '_')}/{name.lower().replace(' ','_')}_triplets_no_dupes.xlsx"
    filepath = 'data/all_triplets_no_dupes.xlsx' # For unfiltered version of the code
    
    try:
        df = pd.read_excel(filepath)
    except FileNotFoundError:
        continue

    triplets = set(df.itertuples(index=False, name=None))
    triplets = list(triplets)
    length = len(triplets)

    if length > 0:
        graph = propagate(name, set(), triplets, set(), threshold=0.9)
    results[name] = list(graph)

filepath = f'{base_directory}/graphs.json'
print(f'Saving results to {filepath}...')
with open(filepath, 'w') as file:
    json.dump(results, file, indent=4, ensure_ascii=False)

print('\n')
# Out:
# Saving results to data/unfiltered/graphs.json...
